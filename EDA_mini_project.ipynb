# %% [markdown]
# <a href="https://colab.research.google.com/github/Shaif95/AI_camp/blob/main/EDA_mini_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install wget
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: wget in /usr/local/lib/python3.10/dist-packages (3.2)

# %%
import wget

url = "https://raw.githubusercontent.com/Shaif95/AI_camp/main/usa.csv"
filename = wget.download(url)
import pandas as pd

df = pd.read_csv(filename)
df.head(5)
# Out:
#   Country  Year State/Province ISO_Code  Economic Freedom Summary Index  Rank  \
# 0     USA  2020         Alaska    US-AK                            5.32    40
# 1     USA  2020        Alabama    US-AL                            6.41    22
# 2     USA  2020       Arkansas    US-AR                            6.30    27
# 3     USA  2020        Arizona    US-AZ                            5.87    32
# 4     USA  2020     California    US-CA                            4.59    49
#
#    Quantile  General Consumption Expenditure  Transfers and subsidies  \
# 0         4                             2.79                     6.00
# 1         2                             6.91                     4.51
# 2         3                             7.72                     6.14
# 3         3                             9.32                     0.00
# 4         4                             6.58                     3.56
#
#    Insurance and Retirement Payments  ...  Sales Tax Revenue  Taxes  \
# 0                               0.00  ...               8.81   8.35
# 1                               5.31  ...               4.00   7.18
# 2                               6.65  ...               2.78   6.41
# 3                               6.11  ...               3.97   7.16
# 4                               0.75  ...               5.83   4.77
#
#    Minimum Wage Legislation  Government Employment  Union Density  \
# 0                      6.76                   3.08           4.19
# 1                      6.87                   5.03           7.51
# 2                      2.95                   5.91           8.07
# 3                      1.17                   8.59           6.19
# 4                      5.93                   7.75           2.45
#
#    Hiring regulations and minimum wage  Labor Market Freedom  \
# 0                                  NaN                   NaN
# 1                                  NaN                   NaN
# 2                                  NaN                   NaN
# 3                                  NaN                   NaN
# 4                                  NaN                   NaN
#
#    Credit Market Regulation  Business Regulations  Labor Market Freedom.1
# 0                       NaN                   NaN                    4.68
# 1                       NaN                   NaN                    6.47
# 2                       NaN                   NaN                    5.65
# 3                       NaN                   NaN                    5.31
# 4                       NaN                   NaN                    5.38
#
# [5 rows x 27 columns]

# %%
df.columns
# Out:
# Index(['Country', 'Year', 'State/Province', 'ISO_Code',
#        'Economic Freedom Summary Index', 'Rank', 'Quantile',
#        'General Consumption Expenditure', 'Transfers and subsidies',
#        'Insurance and Retirement Payments',
#        'Government enterprises and investment', 'Government Spending',
#        'Income and Payroll Tax Revenue', 'Top Marginal Income Tax Rate',
#        'Top Marginal Income Payroll tax Rate', 'world-adjusted',
#        'Property Tax and Other Taxes', 'Sales Tax Revenue', 'Taxes',
#        'Minimum Wage Legislation', 'Government Employment', 'Union Density',
#        'Hiring regulations and minimum wage', 'Labor Market Freedom',
#        'Credit Market Regulation', 'Business Regulations',
#        'Labor Market Freedom.1'],
#       dtype='object')

# %%
url = "https://raw.githubusercontent.com/Shaif95/AI_camp/main/world.csv"
import pandas as pd

df = pd.read_csv(filename)
df.head(5)
# Out:
#   Country  Year State/Province ISO_Code  Economic Freedom Summary Index  Rank  \
# 0     USA  2020         Alaska    US-AK                            5.32    40
# 1     USA  2020        Alabama    US-AL                            6.41    22
# 2     USA  2020       Arkansas    US-AR                            6.30    27
# 3     USA  2020        Arizona    US-AZ                            5.87    32
# 4     USA  2020     California    US-CA                            4.59    49
#
#    Quantile  General Consumption Expenditure  Transfers and subsidies  \
# 0         4                             2.79                     6.00
# 1         2                             6.91                     4.51
# 2         3                             7.72                     6.14
# 3         3                             9.32                     0.00
# 4         4                             6.58                     3.56
#
#    Insurance and Retirement Payments  ...  Sales Tax Revenue  Taxes  \
# 0                               0.00  ...               8.81   8.35
# 1                               5.31  ...               4.00   7.18
# 2                               6.65  ...               2.78   6.41
# 3                               6.11  ...               3.97   7.16
# 4                               0.75  ...               5.83   4.77
#
#    Minimum Wage Legislation  Government Employment  Union Density  \
# 0                      6.76                   3.08           4.19
# 1                      6.87                   5.03           7.51
# 2                      2.95                   5.91           8.07
# 3                      1.17                   8.59           6.19
# 4                      5.93                   7.75           2.45
#
#    Hiring regulations and minimum wage  Labor Market Freedom  \
# 0                                  NaN                   NaN
# 1                                  NaN                   NaN
# 2                                  NaN                   NaN
# 3                                  NaN                   NaN
# 4                                  NaN                   NaN
#
#    Credit Market Regulation  Business Regulations  Labor Market Freedom.1
# 0                       NaN                   NaN                    4.68
# 1                       NaN                   NaN                    6.47
# 2                       NaN                   NaN                    5.65
# 3                       NaN                   NaN                    5.31
# 4                       NaN                   NaN                    5.38
#
# [5 rows x 27 columns]

# %%
df.columns
# Out:
# Index(['Country', 'Year', 'State/Province', 'ISO_Code',
#        'Economic Freedom Summary Index', 'Rank', 'Quantile',
#        'General Consumption Expenditure', 'Transfers and subsidies',
#        'Insurance and Retirement Payments',
#        'Government enterprises and investment', 'Government Spending',
#        'Income and Payroll Tax Revenue', 'Top Marginal Income Tax Rate',
#        'Top Marginal Income Payroll tax Rate', 'world-adjusted',
#        'Property Tax and Other Taxes', 'Sales Tax Revenue', 'Taxes',
#        'Minimum Wage Legislation', 'Government Employment', 'Union Density',
#        'Hiring regulations and minimum wage', 'Labor Market Freedom',
#        'Credit Market Regulation', 'Business Regulations',
#        'Labor Market Freedom.1'],
#       dtype='object')

# %% [markdown]
# # Welcome to your first EDA \(Exploratory Data Analysis\)

# %% [markdown]
# ### Our task at hand \-\- I hope you like penguins!
#
# For our mini project, we are going to use Pandas to conduct a basic Exploratory Data Analysis on a penguins dataset. Specifically, we are looking at the <u>Palmer Archipelago \(Antarctica\) Penguins</u> dataset, which you can find here:  [https://raw.githubusercontent.com/mcnakhaee/palmerpenguins/master/palmerpenguins/data/penguins\-raw.csv](https://raw.githubusercontent.com/mcnakhaee/palmerpenguins/master/palmerpenguins/data/penguins-raw.csv)
#
# Not sure what an exploratory data analysis is? You can google it! The best definition I found is below:
#
# _**Exploratory Data Analysis**_ **refers to the critical process of performing initial investigations on data so as to discover patterns, to spot anomalies, to test hypotheses and to check assumptions with the help of summary statistics and graphical representations.**

# %%
#Before anything else let's import our library for data analysis, pandas.
import pandas as pd

# %% [markdown]
# ### Step 1: Loading in and understanding our data
#
# We need to read in our data. It is currently a .csv \(comma\-separated value\) file, and we generally use the pd.read\_csv\(\) function from pandas to read our data into a dataframe.

# %%
penguins_dataframe = pd.read_csv("https://raw.githubusercontent.com/mcnakhaee/palmerpenguins/master/palmerpenguins/data/penguins-raw.csv")

# %% [markdown]
# **TODO:** Can you run the .head\(\) and .tail\(\) function on our new dataframe? Can you print the name of all the columns in our dataframe? How about the number of rows?

# %%
# Run head() on penguins_dataframe
penguins_dataframe.head(5)
# Out:
#   studyName  Sample Number                              Species  Region  \
# 0   PAL0708              1  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 1   PAL0708              2  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 2   PAL0708              3  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 3   PAL0708              4  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 4   PAL0708              5  Adelie Penguin (Pygoscelis adeliae)  Anvers
#
#       Island               Stage Individual ID Clutch Completion    Date Egg  \
# 0  Torgersen  Adult, 1 Egg Stage          N1A1               Yes  2007-11-11
# 1  Torgersen  Adult, 1 Egg Stage          N1A2               Yes  2007-11-11
# 2  Torgersen  Adult, 1 Egg Stage          N2A1               Yes  2007-11-16
# 3  Torgersen  Adult, 1 Egg Stage          N2A2               Yes  2007-11-16
# 4  Torgersen  Adult, 1 Egg Stage          N3A1               Yes  2007-11-16
#
#    Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  Body Mass (g)  \
# 0                39.1               18.7                181.0         3750.0
# 1                39.5               17.4                186.0         3800.0
# 2                40.3               18.0                195.0         3250.0
# 3                 NaN                NaN                  NaN            NaN
# 4                36.7               19.3                193.0         3450.0
#
#       Sex  Delta 15 N (o/oo)  Delta 13 C (o/oo)  \
# 0    MALE                NaN                NaN
# 1  FEMALE            8.94956          -24.69454
# 2  FEMALE            8.36821          -25.33302
# 3     NaN                NaN                NaN
# 4  FEMALE            8.76651          -25.32426
#
#                          Comments
# 0  Not enough blood for isotopes.
# 1                             NaN
# 2                             NaN
# 3              Adult not sampled.
# 4                             NaN

# %%
# Run tail() on penguins_dataframe

# %%
# Print the name of all the columns in our dataframe
penguins_dataframe.columns
# Out:
# Index(['studyName', 'Sample Number', 'Species', 'Region', 'Island', 'Stage',
#        'Individual ID', 'Clutch Completion', 'Date Egg', 'Culmen Length (mm)',
#        'Culmen Depth (mm)', 'Flipper Length (mm)', 'Body Mass (g)', 'Sex',
#        'Delta 15 N (o/oo)', 'Delta 13 C (o/oo)', 'Comments'],
#       dtype='object')

# %%
# Use google to find out how to print the number of rows and columsn in this dataset.

penguins_dataframe.shape[1]
# Out:
# 17

# %% [markdown]
# ### Step 2: Do your research
#
# What do the column names mean? At this point you should look up the meanings of any columns you don't know about and make some comments below.
#
# Typically at this point we would read up on the domain we are performing data analysis on. To do research on penguins you should probably get to know something about penguins!

# %% [raw]
# What do these columns mean?

# %% [markdown]
# ### Step 3: Cleaning up our Data
#
# This data is a lot to take in. How do we know if we can even use this data? I see some weird columns and lots of N/A values.
#
# Let's talk through some functions to clean our data and see if it is salvagable. To start, we cannot use all of these columns. I'm thinking I want to get rid of "studyName" and "Comments" since they are not super useful for understanding the data relationships. I'll do that below.

# %%
#Make a list of what you want to drop
columns_to_drop = ['studyName', 'Comments']

#Drop the columns using drop()
penguins_dataframe.drop(columns_to_drop, axis=1, inplace = True) #axis = 1 lets pandas know we are dropping columns, not rows.

#Check that they are dropped
penguins_dataframe.head(1)
# Out:
#    Sample Number                              Species  Region     Island  \
# 0              1  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
#
#                 Stage Individual ID Clutch Completion    Date Egg  \
# 0  Adult, 1 Egg Stage          N1A1               Yes  2007-11-11
#
#    Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  Body Mass (g)  \
# 0                39.1               18.7                181.0         3750.0
#
#     Sex  Delta 15 N (o/oo)  Delta 13 C (o/oo)
# 0  MALE                NaN                NaN

# %% [markdown]
# **What does inplace mean?** This argument in the `drop()` function means we are changing the dataframe in place! If we had `inplace = False`, we would need to create a new dataframe like so:
#
# `new_penguins_dataframe = penguins_dataframe.drop(columns_to_drop, axis=1, inplace = False)`
#
# **TODO:** Can you drop the Sample Number, Individual ID, Delta 15 N \(o/oo\), and Delta 13 C \(o/oo\) columns using the example above?

# %%
# Drop the Sample Number, Individual ID, Delta 15 N (o/oo), and Delta 13 C (o/oo) columns using the example above.
penguins_dataframe.drop(["Sample Number", "Individual ID", "Delta 15 N (o/oo)", "Delta 13 C (o/oo)"],axis = 1, inplace = True)

#Drop the columns using drop()


#Check that they are dropped head()
penguins_dataframe.head(2)
# Out:
#                                Species  Region     Island               Stage  \
# 0  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen  Adult, 1 Egg Stage
# 1  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen  Adult, 1 Egg Stage
#
#   Clutch Completion    Date Egg  Culmen Length (mm)  Culmen Depth (mm)  \
# 0               Yes  2007-11-11                39.1               18.7
# 1               Yes  2007-11-11                39.5               17.4
#
#    Flipper Length (mm)  Body Mass (g)     Sex
# 0                181.0         3750.0    MALE
# 1                186.0         3800.0  FEMALE

# %% [markdown]
# #### Getting Rid of N/A's
#
# I see lots of N/A's, which we typically cannot visualize or use in machine learning.
# Now, I want to get rid of all the rows that have NA's in them. I'll show you how. **TODO:** Can you print the number of rows our dataframe has after I drop the NAs?

# %%
# This is a very convenient function to drop all rows that have N/A values!
penguins_dataframe.dropna(inplace=True)
penguins_dataframe.reset_index(drop=True, inplace=True) #Very good practice to reset how your rows are counted when you drop rows.

# %%
#Print the number of rows our new dataframe has.
penguins_dataframe.shape[0]
# Out:
# 333

# %% [markdown]
# ### Exploring the Data
#
# Pandas has some amazing tools for exploring your data. Since this is a **mini** project, we will walk through only a few key features of pandas exploration. You can expect to do lots of research on your own to best explore, clean, and visualize your data for your project.
#
# First we will learn how to access certain columns of data and use conditions to get subsets of data.

# %%
# access a column using df["<COLUMN_NAME"] or df.COLUMN_NAME
penguins_dataframe["Species"].head()
# Out:
# 0    Adelie Penguin (Pygoscelis adeliae)
# 1    Adelie Penguin (Pygoscelis adeliae)
# 2    Adelie Penguin (Pygoscelis adeliae)
# 3    Adelie Penguin (Pygoscelis adeliae)
# 4    Adelie Penguin (Pygoscelis adeliae)
# Name: Species, dtype: object

# %%
penguins_dataframe.Island.head()
# Out:
# 0    Torgersen
# 1    Torgersen
# 2    Torgersen
# 3    Torgersen
# 4    Torgersen
# Name: Island, dtype: object

# %%
#You can also access multiple columns using double brackets (printing a "list" of columns)
penguins_dataframe[["Species","Region"]].head(10)
# Out:
#                                Species  Region
# 0  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 1  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 2  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 3  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 4  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 5  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 6  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 7  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 8  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 9  Adelie Penguin (Pygoscelis adeliae)  Anvers

# %% [markdown]
# **TODO: Can you print the last five rows of the Island and Region columns?**

# %%
#Print the last five rows of the Island and Region columns.
penguins_dataframe[["Island", "Region"]].tail(5)
# Out:
#     Island  Region
# 328  Dream  Anvers
# 329  Dream  Anvers
# 330  Dream  Anvers
# 331  Dream  Anvers
# 332  Dream  Anvers

# %% [markdown]
# <u>**Conditions in Pandas**</u>
#
# Pandas is also incredible for selecting subsets of columns that fit a certain condition. Check out the code below to get only the Adelie penguins.

# %%
penguins_dataframe[penguins_dataframe["Species"] == "Adelie Penguin (Pygoscelis adeliae)"].head()
# Out:
#                                Species  Region     Island               Stage  \
# 0  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen  Adult, 1 Egg Stage
# 1  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen  Adult, 1 Egg Stage
# 2  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen  Adult, 1 Egg Stage
# 3  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen  Adult, 1 Egg Stage
# 4  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen  Adult, 1 Egg Stage
#
#   Clutch Completion    Date Egg  Culmen Length (mm)  Culmen Depth (mm)  \
# 0               Yes  2007-11-11                39.1               18.7
# 1               Yes  2007-11-11                39.5               17.4
# 2               Yes  2007-11-16                40.3               18.0
# 3               Yes  2007-11-16                36.7               19.3
# 4               Yes  2007-11-16                39.3               20.6
#
#    Flipper Length (mm)  Body Mass (g)     Sex
# 0                181.0         3750.0    MALE
# 1                186.0         3800.0  FEMALE
# 2                195.0         3250.0  FEMALE
# 3                193.0         3450.0  FEMALE
# 4                190.0         3650.0    MALE

# %% [markdown]
# Conditions in pandas work just like `if` statements in python.
#
# **TODO: Can you tell me which species of penguin can have a flipper length greater than or equal to 230 by using conditions in pandas?**

# %%
# Use pandas to find out which species of penguin can have a flipper length greater than or equal to 230
species = penguins_dataframe[penguins_dataframe["Flipper Length (mm)"]  >= 230]
species[["Species"]].head()
# Out:
#                                Species
# 147  Gentoo penguin (Pygoscelis papua)
# 178  Gentoo penguin (Pygoscelis papua)
# 208  Gentoo penguin (Pygoscelis papua)
# 210  Gentoo penguin (Pygoscelis papua)
# 219  Gentoo penguin (Pygoscelis papua)

# %% [markdown]
# **TODO:** Take 5 minutes to explore the dataset on your own. There's some space for you to code below.
#
# Think of what you want to learn. Maybe what the smallest flipper size penguin is? How about the smallest culmen width? What is the largest penguin by mass?

# %%
#Create a pie plot here - might look more like art than data science. Is a pie chart a good choice for the column?
import pandas as pd
values = penguins_dataframe['Body Mass (g)'].value_counts().head(10)

values.plot.pie()
plt.title("the Pie Chart")

plt.show()

# %% [markdown]
# ### Visualize on the Fly with Pandas
#
# Before we create mind\-blowing visualizations, it is sometimes worth it to create quick visualizations to get ourselves oriented with the data and it's underlying patterns.
#
# I put a simple histogram below that helps me understand how the dataset is distributed. Notice that is is pretty hard to read and ugly, but it gets the job done for the data scientist. I now know that there are three species of penguin we are worried about, and that we have a lot more samples of the Adelie penguin than the Gentoo and Chinstrap \(a good to know for machine learning\).

# %%
penguins_dataframe["Species"].value_counts().plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# **TODO: Create a histogram of another column of your choice below.**

# %%
#Create a histogram of another column of your choice below.
#Create a histogram of another column of your choice below.
penguins_dataframe["Body Mass (g)"].hist()
# Out:
# <Axes: >

# %%
penguins_dataframe.hist()
# Out:
# array([[<Axes: title={'center': 'Culmen Length (mm)'}>,
#         <Axes: title={'center': 'Culmen Depth (mm)'}>],
#        [<Axes: title={'center': 'Flipper Length (mm)'}>,
#         <Axes: title={'center': 'Body Mass (g)'}>]], dtype=object)

# %% [markdown]
# **TODO:** Now, let's have some fun. Can you create plots using the following functions?
#
# 1. Scatter Plot: [https://pandas.pydata.org/pandas\-docs/version/0.25.0/reference/api/pandas.DataFrame.plot.scatter.html](https://pandas.pydata.org/pandas-docs/version/0.25.0/reference/api/pandas.DataFrame.plot.scatter.html)
# 2. Pie Plot: [https://pandas.pydata.org/docs/user\_guide/visualization.html\#visualization\-pie](https://pandas.pydata.org/docs/user_guide/visualization.html#visualization-pie)
#
# Pro challenge: Add a title to each!

# %%
#Create a scatter here
#Create a scatter here
penguins_dataframe.plot.scatter("Species", "Body Mass (g)")
# Out:
# <Axes: xlabel='Species', ylabel='Body Mass (g)'>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'penguins_dataframe' is your dataframe
region_counts = penguins_dataframe['Island'].value_counts()

# Plotting the pie chart
region_counts.plot.pie(autopct='%1.1f%%')

# Adding a title
plt.title('Distribution of Penguins by Region')

# Display the plot
plt.show()

# %% [markdown]
# ### Creating Beautiful Visualizations with Plotly
#
# So far, it looks like a scatter plot might be our best bet! Now we want to make a beautiful scatter plot using `plotly.`Just like pandas and numpy, plotly is a module that lets us create beautiful visualizations in just a few lines of code.
#
# I'm only going to help with the import, so I need you to spend time on plotly's documentation in order to build the same scatter plot you did in the last section, but nicer. Maybe google "Scatter plots in plotly python" to start!

# %%
import plotly.express as px #importing plotly

# %% [markdown]
# **TODO:** Create a scatter plot using plotly. Please add a title here!
#
# Maybe google "Scatter plots in plotly python" to start!

# %%
# Create a scatter plot
# Create the same scatter plot with color="Species". Feeling crazy? Set a column name to the "size" argument as well!
fig = px.scatter(penguins_dataframe, x="Body Mass (g)", y="Species", color="Body Mass (g)", title="the Standard Scatter")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="8dd661a0-e744-4cc6-9ed7-c914d3e2cef1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8dd661a0-e744-4cc6-9ed7-c914d3e2cef1")) {                    Plotly.newPlot(                        "8dd661a0-e744-4cc6-9ed7-c914d3e2cef1",                        [{"hovertemplate":"Body Mass (g)=%{marker.color}<br>Species=%{y}<extra></extra>","legendgroup":"","marker":{"color":[3750.0,3800.0,3250.0,3450.0,3650.0,3625.0,4675.0,3200.0,3800.0,4400.0,3700.0,3450.0,4500.0,3325.0,4200.0,3400.0,3600.0,3800.0,3950.0,3800.0,3800.0,3550.0,3200.0,3150.0,3950.0,3250.0,3900.0,3300.0,3900.0,3325.0,4150.0,3950.0,3550.0,3300.0,4650.0,3150.0,3900.0,3100.0,4400.0,3000.0,4600.0,3425.0,3450.0,4150.0,3500.0,4300.0,3450.0,4050.0,2900.0,3700.0,3550.0,3800.0,2850.0,3750.0,3150.0,4400.0,3600.0,4050.0,2850.0,3950.0,3350.0,4100.0,3050.0,4450.0,3600.0,3900.0,3550.0,4150.0,3700.0,4250.0,3700.0,3900.0,3550.0,4000.0,3200.0,4700.0,3800.0,4200.0,3350.0,3550.0,3800.0,3500.0,3950.0,3600.0,3550.0,4300.0,3400.0,4450.0,3300.0,4300.0,3700.0,4350.0,2900.0,4100.0,3725.0,4725.0,3075.0,4250.0,2925.0,3550.0,3750.0,3900.0,3175.0,4775.0,3825.0,4600.0,3200.0,4275.0,3900.0,4075.0,2900.0,3775.0,3350.0,3325.0,3150.0,3500.0,3450.0,3875.0,3050.0,4000.0,3275.0,4300.0,3050.0,4000.0,3325.0,3500.0,3500.0,4475.0,3425.0,3900.0,3175.0,3975.0,3400.0,4250.0,3400.0,3475.0,3050.0,3725.0,3000.0,3650.0,4250.0,3475.0,3450.0,3750.0,3700.0,4000.0,4500.0,5700.0,4450.0,5700.0,5400.0,4550.0,4800.0,5200.0,4400.0,5150.0,4650.0,5550.0,4650.0,5850.0,4200.0,5850.0,4150.0,6300.0,4800.0,5350.0,5700.0,5000.0,4400.0,5050.0,5000.0,5100.0,5650.0,4600.0,5550.0,5250.0,4700.0,5050.0,6050.0,5150.0,5400.0,4950.0,5250.0,4350.0,5350.0,3950.0,5700.0,4300.0,4750.0,5550.0,4900.0,4200.0,5400.0,5100.0,5300.0,4850.0,5300.0,4400.0,5000.0,4900.0,5050.0,4300.0,5000.0,4450.0,5550.0,4200.0,5300.0,4400.0,5650.0,4700.0,5700.0,5800.0,4700.0,5550.0,4750.0,5000.0,5100.0,5200.0,4700.0,5800.0,4600.0,6000.0,4750.0,5950.0,4625.0,5450.0,4725.0,5350.0,4750.0,5600.0,4600.0,5300.0,4875.0,5550.0,4950.0,5400.0,4750.0,5650.0,4850.0,5200.0,4925.0,4875.0,4625.0,5250.0,4850.0,5600.0,4975.0,5500.0,5500.0,4700.0,5500.0,4575.0,5500.0,5000.0,5950.0,4650.0,5500.0,4375.0,5850.0,6000.0,4925.0,4850.0,5750.0,5200.0,5400.0,3500.0,3900.0,3650.0,3525.0,3725.0,3950.0,3250.0,3750.0,4150.0,3700.0,3800.0,3775.0,3700.0,4050.0,3575.0,4050.0,3300.0,3700.0,3450.0,4400.0,3600.0,3400.0,2900.0,3800.0,3300.0,4150.0,3400.0,3800.0,3700.0,4550.0,3200.0,4300.0,3350.0,4100.0,3600.0,3900.0,3850.0,4800.0,2700.0,4500.0,3950.0,3650.0,3550.0,3500.0,3675.0,4450.0,3400.0,4300.0,3250.0,3675.0,3325.0,3950.0,3600.0,4050.0,3350.0,3450.0,3250.0,4050.0,3800.0,3525.0,3950.0,3650.0,3650.0,4000.0,3400.0,3775.0,4100.0,3775.0],"coloraxis":"coloraxis","symbol":"circle"},"mode":"markers","name":"","orientation":"h","showlegend":false,"x":[3750.0,3800.0,3250.0,3450.0,3650.0,3625.0,4675.0,3200.0,3800.0,4400.0,3700.0,3450.0,4500.0,3325.0,4200.0,3400.0,3600.0,3800.0,3950.0,3800.0,3800.0,3550.0,3200.0,3150.0,3950.0,3250.0,3900.0,3300.0,3900.0,3325.0,4150.0,3950.0,3550.0,3300.0,4650.0,3150.0,3900.0,3100.0,4400.0,3000.0,4600.0,3425.0,3450.0,4150.0,3500.0,4300.0,3450.0,4050.0,2900.0,3700.0,3550.0,3800.0,2850.0,3750.0,3150.0,4400.0,3600.0,4050.0,2850.0,3950.0,3350.0,4100.0,3050.0,4450.0,3600.0,3900.0,3550.0,4150.0,3700.0,4250.0,3700.0,3900.0,3550.0,4000.0,3200.0,4700.0,3800.0,4200.0,3350.0,3550.0,3800.0,3500.0,3950.0,3600.0,3550.0,4300.0,3400.0,4450.0,3300.0,4300.0,3700.0,4350.0,2900.0,4100.0,3725.0,4725.0,3075.0,4250.0,2925.0,3550.0,3750.0,3900.0,3175.0,4775.0,3825.0,4600.0,3200.0,4275.0,3900.0,4075.0,2900.0,3775.0,3350.0,3325.0,3150.0,3500.0,3450.0,3875.0,3050.0,4000.0,3275.0,4300.0,3050.0,4000.0,3325.0,3500.0,3500.0,447 ...

# %%
#Pie Plot
import pandas as pd
import plotly.express as px

# Assuming 'penguins_dataframe' is your dataframe
region_counts = penguins_dataframe['Island'].value_counts()

# Creating the pie chart using Plotly
fig = px.pie(region_counts, values=region_counts.values, names=region_counts.index, labels=region_counts.index,
             title='Distribution of Penguins by Region')

# Display the plot
fig.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/plotly/express/_core.py:137: FutureWarning:
#
# Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="2fb69fbf-748e-444f-bb37-a32ae76bdf85" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2fb69fbf-748e-444f-bb37-a32ae76bdf85")) {                    Plotly.newPlot(                        "2fb69fbf-748e-444f-bb37-a32ae76bdf85",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"index=%{label}<br>value=%{value}<extra></extra>","labels":["Biscoe","Dream","Torgersen"],"legendgroup":"","name":"","showlegend":true,"values":[163,123,47],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size": ...

# %% [markdown]
# **TODO:** Let's make it look even better. Copy your function from above but add another argument to the function by setting the `color="Species"`. Not sure what this means? Get to the scatter plots page on plotly and scroll down to the "Setting size and color with column names" section.

# %%
# Create the same scatter plot with color="Species". Feeling crazy? Set a column name to the "size" argument as well!

# %% [markdown]
# **Scatter Matrix:** I wanted to create a scatter plot for every possible numerical combination of 'Culmen Length \(mm\)', 'Culmen Depth \(mm\)', 'Flipper Length \(mm\)', and 'Body Mass \(g\)'. This could help me understand what is correlated and could mean a relationship between each other. The code to do so is below; are there any findings you can take away from this data?

# %%
# My scatter matrix!
numerical_penguins_df = penguins_dataframe[['Culmen Length (mm)', 'Culmen Depth (mm)', 'Flipper Length (mm)',
# %% [markdown]
# ### Putting the DA in EDA
#
# We now have explored our data some, and have built some beautiful visualizations to showcase patterns our data. But having a plot doesn't mean anything to someone who can't understand how to read plots.
#
# Below you can continue your analysis if you have hypotheses you'd like to explore with the penguins \(i.e. is flipper length related to culmen depth? Which species has the largest culmen area?\). After you are done, please write up some descriptions for your findings on this dataset. One question we answered earlier was _which species has the largest flipper length?_ You can start with you

# %%
#Continue your analysis below -- try something new!

# %%
#Continue your analysis

# %% [raw]
# Write up some descriptions for your findings here....

# %% [markdown]
# ## Extra Libraries
#
# We have used plotly which is a fairly simple library for data visualization. There exists other libraries that are much more powerful. We are going to explore two libraries: Seaborn and Matplotlib! Seaborn and Matplotlib are built on top of each other.
#
# Seaborn is strong for statistical data and complex data-set.
# MatplotLib is very good for customizing the visualization such as titles, adjusting scales, etc.
# When in doubt, google!

# %% [markdown]
# ### Seaborn
#
# With seaborn, we will make 3 graphs: a scatterplot, a overlaid histogram, and a line graph

# %%
### SCATTERPLOT ###
# Import seaborn
import seaborn as sns

# Apply the default theme
sns.set_theme()

# Using the same penguins dataframe
penguins_dataframe = pd.read_csv("https://raw.githubusercontent.com/mcnakhaee/palmerpenguins/master/palmerpenguins/data/penguins-raw.csv")

# Create a visualization
sns.scatterplot(
    data=penguins_dataframe,
    x="Culmen Length (mm)", y="Culmen Depth (mm)",
    hue="Species",
)
# Out:
# <Axes: xlabel='Culmen Length (mm)', ylabel='Culmen Depth (mm)'>

# %%
### HISTOGRAM ###
sns.histplot(penguins_dataframe, x = 'Flipper Length (mm)', hue = 'Sex')
# Out:
# <Axes: xlabel='Flipper Length (mm)', ylabel='Count'>

# %%
### LINE GRAPH ###
sns.lineplot(
    data=penguins_dataframe,
    x = 'Body Mass (g)', y = 'Flipper Length (mm)',
    hue = 'Sex'
)
# Out:
# <Axes: xlabel='Body Mass (g)', ylabel='Flipper Length (mm)'>

# %% [markdown]
# ### Matplotlib
# Matplotlib is another powerful Python visualization library for data plotting and explorations. We will use it today to easily add and change titles and labels on our plots

# %%
# Import Matplotlib
import matplotlib
import matplotlib.pyplot as plt

# Plot our seaborn scatterplot from the previous step
sns.scatterplot(
    data=penguins_dataframe,
    x="Culmen Length (mm)", y="Culmen Depth (mm)",
    hue="Sex",
)

# Add a title to our graph and change the legend title!
plt.title("Culmen Length vs Culmen Depth")
plt.legend(title = 'Gender')

# %% [markdown]
# Here is another example of editing the titles and axis labels. This is a very important step in data visualization as it provides clarity and interpretation to our viewers

# %%
# Plot our seaborn histogram from an earlier step
sns.histplot(penguins_dataframe, x = 'Flipper Length (mm)', hue = 'Sex')

# Add a descriptive title to our histogram!
plt.title("Distribution of Flipper Lengths Based on Gender")

# Change x-axis label
plt.xlabel('Flipper Length in millimeters')
# Out:
# Text(0.5, 0, 'Flipper Length in millimeters')

# %% [markdown]
# Thank you!
